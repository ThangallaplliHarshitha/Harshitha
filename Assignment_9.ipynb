# %% [markdown]
# <a href="https://colab.research.google.com/github/ThangallaplliHarshitha/Harshitha/blob/main/Assignment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn.datasets
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/content/loan_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# min     612.000000         178.958333  0.000000e+00     0.000000
# 25%     682.000000        2820.000000  3.187000e+03    22.600000
# 50%     707.000000        4139.958333  8.596000e+03    46.300000
# 75%     737.000000        5730.000000  1.824950e+04    70.900000
# max     827.000000       17639.958330  1.207359e+06   119.000000
#
#        inq.last.6mths  delinq.2yrs      pub.rec  not.fully.paid
# count     9578.000000  9578.000000  9578.000000     9578.000000
# mean         1.577469     0.163708     0.062122        0.160054
# std          2.200245     0.546215     0.262126        0.366676
# min          0.000000     0.000000     0.000000        0.000000
# 25%          0.000000     0.000000     0.000000        0.000000
# 50%          1.000000     0.000000     0.000000        0.000000
# 75%          2.000000     0.000000     0.000000        0.000000
# max         33.000000    13.000000     5.000000        1.000000

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0
# 2            0        0               0
# 3            0        0               0
# 4            1        0               0

# %%
print("following is a breakup of credit approval staus\n .")
print(df['credit.policy'].value_counts())
# Out:
# following is a breakup of credit approval staus
#  .
# credit.policy
# 1    7710
# 0    1868
# Name: count, dtype: int64

# %%
print(f"Top 5 Installments : { df['installment'].value_counts()}")
# Out:
# Top 5 Installments : installment
# 317.72    41
# 316.11    34
# 319.47    29
# 381.26    27
# 662.68    27
#           ..
# 97.53      1
# 76.26      1
# 150.84     1
# 158.99     1
# 853.43     1
# Name: count, Length: 4788, dtype: int64

# %%
df['int.rate'].hist(bins=40,label="top 5 Int.Rates")
plt.legend(fontsize=15)
plt.title("Histogram of Interest Rates",fontsize=16)
plt.xlabel("FICO score",fontsize=14)
# Out:
# Text(0.5, 0, 'FICO score')

# %%
df[df['credit.policy']==1]['fico'].plot.hist(bins=30,alpha=0.5 ,color='blue',label='credit.policy=1')
df[df['credit.policy']==0]['fico'].plot.hist(bins=30,alpha=0.5 ,color='red',label='credit.policy=0')
plt.legend(fontsize=15)
plt.title("histogram of FISCO score based credit policies",fontsize=15)
plt.xlabel("FICO score",fontsize=14)
# Out:
# Text(0.5, 0, 'FICO score')

# %%
sns.jointplot(x='fico',y='int.rate',data=df,color='purple',size=12)

# %%
df_final=pd.get_dummies(df,['purpose'],drop_first=True)

# %%
df.shape,df_final.shape,df_final.columns[14:]
# Out:
# ((9578, 14),
#  (9578, 19),
#  Index(['purpose_debt_consolidation', 'purpose_educational',
#         'purpose_home_improvement', 'purpose_major_purchase',
#         'purpose_small_business'],
#        dtype='object'))

# %%
from sklearn.model_selection import train_test_split
X=df_final.drop('not.fully.paid',axis=1)
y=df_final['not.fully.paid']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=150)

# %%
df.shape,X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((9578, 14), (7662, 18), (7662,), (1916, 18), (1916,))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier(criterion='gini',max_depth=None)

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=dtree.predict(X_test)
train_pred=dtree.predict(X_train)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
print(f"Accuracy of Train:{accuracy_score(y_train,train_pred)}")
print(f"Accuracy of Train:{accuracy_score(y_test,predictions)}")
# Out:
# Accuracy of Train:1.0
# Accuracy of Train:0.7160751565762005

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      1596
#            1       0.18      0.20      0.19       320
#
#     accuracy                           0.72      1916
#    macro avg       0.51      0.51      0.51      1916
# weighted avg       0.73      0.72      0.72      1916

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=600)

# %%
rfc_pred=rfc.predict(X_test)
rfc_train_pred=rfc.predict(X_train)

# %%
print(f"Accuracy of Train:{accuracy_score(y_train,rfc_train_pred)}")
print(f"Accuracy of Train:{accuracy_score(y_test,rfc_pred)}")
# Out:
# Accuracy of Train:1.0
# Accuracy of Train:0.8319415448851775

# %%
cr=classification_report(y_test,rfc_pred)
print(f"Misclassification Error:{np.mean(rfc_pred!=y_test).sum()}")
# Out:
# Misclassification Error:0.16805845511482254

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      1596
#            1       0.42      0.02      0.03       320
#
#     accuracy                           0.83      1916
#    macro avg       0.63      0.51      0.47      1916
# weighted avg       0.76      0.83      0.76      1916

# %%
cm = confusion_matrix(y_test,rfc_pred)
print(cm)
# Out:
# [[1589    7]
#  [ 315    5]]

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=10,max_depth=None,criterion='gini')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (criterion: 'gini')", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)
# Out:
# Text(0, 0.5, 'Prediction accuracy from confusion matrix')

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=10,max_depth=None,criterion='entropy')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (criterion: 'entropy')", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)
# Out:
# Text(0, 0.5, 'Prediction accuracy from confusion matrix')

# %%
nsimu = 21
accuracy=[0]*nsimu
ntree = [0]*nsimu
for i in range(1,nsimu):
    rfc = RandomForestClassifier(n_estimators=i*5,min_samples_split=10,max_depth=None,criterion='gini')
    rfc.fit(X_train, y_train)
    rfc_pred = rfc.predict(X_test)
    cm = confusion_matrix(y_test,rfc_pred)
    accuracy[i] = (cm[0,0]+cm[1,1])/cm.sum()
    ntree[i]=i*5

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=ntree[1:nsimu],y=accuracy[1:nsimu],s=60,c='red')
plt.title("Number of trees in the Random Forest vs. prediction accuracy (minimum sample split: 20)", fontsize=18)
plt.xlabel("Number of trees", fontsize=15)
plt.ylabel("Prediction accuracy from confusion matrix", fontsize=15)
# Out:
# Text(0, 0.5, 'Prediction accuracy from confusion matrix')
